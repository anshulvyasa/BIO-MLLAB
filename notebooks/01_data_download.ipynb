# %% [markdown]
# # 01 — Download & Explore GSE2034 (GEOparse)
#
# **Goal:** Download the breast cancer microarray dataset **GSE2034** from GEO, cache it locally, and build an expression matrix for downstream analysis.
#
# **What you'll do in this notebook:**
# 1. Set up folders & imports
# 2. Download GSE2034 using `GEOparse`
# 3. Inspect metadata (platforms, samples)
# 4. Build a probe × sample expression matrix (`VALUE`)
# 5. Try basic probe→gene mapping from the GPL annotation
# 6. Save matrices to disk for later notebooks
#
# > Tip: If a step fails due to network hiccups, just re-run the cell.

# %%
import os
import pandas as pd
import numpy as np
from pathlib import Path
from tqdm import tqdm
import GEOparse

# making directory for the data (raw and processed)
PROJECT_ROOT = Path.cwd().parents[0] if (Path.cwd().name == "notebooks") else Path.cwd()
DATA_RAW = PROJECT_ROOT / "data" / "raw" / "GEO"
DATA_PROCESSED = PROJECT_ROOT / "data" / "processed"
REPORTS = PROJECT_ROOT / "reports"

for p in [DATA_RAW, DATA_PROCESSED, REPORTS]:
    p.mkdir(parents=True, exist_ok=True)

print("Project root:", PROJECT_ROOT)
print("Raw GEO cache:", DATA_RAW)
print("Processed:", DATA_PROCESSED)
print("GEOparse version:", GEOparse.__version__)
# Out:
# Project root: c:\Users\Kartikey Samadhiya\Desktop\Desktop\Acads\Projects\ML\MiniProject\BIO-MLLAB
# Raw GEO cache: c:\Users\Kartikey Samadhiya\Desktop\Desktop\Acads\Projects\ML\MiniProject\BIO-MLLAB\data\raw\GEO
# Processed: c:\Users\Kartikey Samadhiya\Desktop\Desktop\Acads\Projects\ML\MiniProject\BIO-MLLAB\data\processed
# GEOparse version: 2.0.4

# %%
# Download the Series GSE2034 and cache in data/raw/GEO
# annotate_gpl=True tries to attach annotation tables (useful later)
gse_id = "GSE2034"
gse = GEOparse.get_GEO(geo=gse_id, destdir=str(DATA_RAW), annotate_gpl=True, how="full")
print(gse)
print("Number of samples (GSM):", len(gse.gsms))
print("Number of platforms (GPL):", len(gse.gpls))
print("Platforms:", list(gse.gpls.keys()))
# Out:
# 19-Nov-2025 09:48:46 DEBUG utils - Directory c:\Users\Kartikey Samadhiya\Desktop\Desktop\Acads\Projects\ML\MiniProject\BIO-MLLAB\data\raw\GEO already exists. Skipping.
# 19-Nov-2025 09:48:46 INFO GEOparse - File already exist: using local version.
# 19-Nov-2025 09:48:46 INFO GEOparse - Parsing c:\Users\Kartikey Samadhiya\Desktop\Desktop\Acads\Projects\ML\MiniProject\BIO-MLLAB\data\raw\GEO\GSE2034_family.soft.gz:
# 19-Nov-2025 09:48:46 DEBUG GEOparse - DATABASE: GeoMiame
# 19-Nov-2025 09:48:46 DEBUG GEOparse - SERIES: GSE2034
# 19-Nov-2025 09:48:47 DEBUG GEOparse - PLATFORM: GPL96
# 19-Nov-2025 09:48:48 DEBUG GEOparse - SAMPLE: GSM36777
# 19-Nov-2025 09:48:48 DEBUG GEOparse - SAMPLE: GSM36778
# 19-Nov-2025 09:48:48 DEBUG GEOparse - SAMPLE: GSM36779
# 19-Nov-2025 09:48:48 DEBUG GEOparse - SAMPLE: GSM36780
# 19-Nov-2025 09:48:48 DEBUG GEOparse - SAMPLE: GSM36781
# 19-Nov-2025 09:48:48 DEBUG GEOparse - SAMPLE: GSM36782
# 19-Nov-2025 09:48:48 DEBUG GEOparse - SAMPLE: GSM36783
# 19-Nov-2025 09:48:48 DEBUG GEOparse - SAMPLE: GSM36784
# 19-Nov-2025 09:48:49 DEBUG GEOparse - SAMPLE: GSM36785
# 19-Nov-2025 09:48:49 DEBUG GEOparse - SAMPLE: GSM36786
# 19-Nov-2025 09:48:49 DEBUG GEOparse - SAMPLE: GSM36787
# 19-Nov-2025 09:48:49 DEBUG GEOparse - SAMPLE: GSM36788
# 19-Nov-2025 09:48:49 DEBUG GEOparse - SAMPLE: GSM36789
# 19-Nov-2025 09:48:49 DEBUG GEOparse - SAMPLE: GSM36790
# 19-Nov-2025 09:48:49 DEBUG GEOparse - SAMPLE: GSM36791
# 19-Nov-2025 09:48:49 DEBUG GEOparse - SAMPLE: GSM36792
# 19-Nov-2025 09:48:49 DEBUG GEOparse - SAMPLE: GSM36793
# 19-Nov-2025 09:48:49 DEBUG GEOparse - SAMPLE: GSM36794
# 19-Nov-2025 09:48:49 DEBUG GEOparse - SAMPLE: GSM36795
# 19-Nov-2025 09:48:49 DEBUG GEOparse - SAMPLE: GSM36796
# 19-Nov-2025 09:48:49 DEBUG GEOparse - SAMPLE: GSM36797
# 19-Nov-2025 09:48:49 DEBUG GEOparse - SAMPLE: GSM36798
# 19-Nov-2025 09:48:49 DEBUG GEOparse - SAMPLE: GSM36799
# 19-Nov-2025 09:48:50 DEBUG GEOparse - SAMPLE: GSM36800
# 19-Nov-2025 09:48:50 DEBUG GEOparse - SAMPLE: GSM36801
# 19-Nov-2025 09:48:50 DEBUG GEOparse - SAMPLE: GSM36802
# 19-Nov-2025 09:48:50 DEBUG GEOparse - SAMPLE: GSM36803
# 19-Nov-2025 09:48:50 DEBUG GEOparse - SAMPLE: GSM36804
# 19-Nov-2025 09:48:50 DEBUG GEOparse - SAMPLE: GSM36805
# 19-Nov-2025 09:48:50 DEBUG GEOparse - SAMPLE: GSM36806
# 19-Nov-2025 09:48:50 DEBUG GEOparse - SAMPLE: GSM36807
# 19-Nov-2025 09:48:50 DEBUG GEOparse - SAMPLE: GSM36808
# 19-Nov-2025 09:48:50 DEBUG GEOparse - SAMPLE: GSM36809
# 19-Nov-2025 09:48:50 DEBUG GEOparse - SAMPLE: GSM36810
# 19-Nov-2025 09:48:50 DEBUG GEOparse - SAMPLE: GSM36811
# 19-Nov-2025 09:48:50 DEBUG GEOparse - SAMPLE: GSM36812
# 19-Nov-2025 09:48:50 DEBUG GEOparse - SAMPLE: GSM36813
# 19-Nov-2025 09:48:50 DEBUG GEOparse - SAMPLE: GSM36814
# 19-Nov-2025 09:48:50 DEBUG GEOparse - SAMPLE: GSM36815
# 19-Nov-2025 09:48:50 DEBUG GEOparse - SAMPLE: GSM36816
# 19-Nov-2025 09:48:51 DEBUG GEOparse - SAMPLE: GSM36817
# 19-Nov-2025 09:48:51 DEBUG GEOparse - SAMPLE: GSM36818
# 19-Nov-2025 09:48:51 DEBUG GEOparse - SAMPLE: GSM36819
# 19-Nov-2025 09:48:51 DEBUG GEOparse - SAMPLE: GSM36820
# 19-Nov-2025 09:48:51 DEBUG GEOparse - SAMPLE: GSM36821
# 19-Nov-2025 09:48:51 DEBUG GEOparse - SAMPLE: GSM36822
# 19-Nov-2025 09:48:51 DEBUG GEOparse - SAMPLE: GSM36823
# 19-Nov-2025 09:48:51 DEBUG GEOparse - SAMPLE: GSM36824
# 19-Nov-2025 09:48:51 DEBUG GEOparse - SAMPLE: GSM36825
# 19-Nov-2025 09:48:51 DEBUG GEOparse - SAMPLE: GSM36826
# 19-Nov-2025 09:48:51 DEBUG GEOparse - SAMPLE: GSM36827
# 19-Nov-2025 09:48:51 DEBUG GEOparse - SAMPLE: GSM36828
# 19-Nov-2025 09:48:51 DEBUG GEOparse - SAMPLE: GSM36829
# 19-Nov-2025 09:48:51 DEBUG GEOparse - SAMPLE: GSM36830
# 19-Nov-2025 09:48:51 DEBUG GEOparse - SAMPLE: GSM36831
# 19-Nov-2025 09:48:51 DEBUG GEOparse - SAMPLE: GSM36832
# 19-Nov-2025 09:48:51 DEBUG GEOparse - SAMPLE: GSM36833
# 19-Nov-2025 09:48:52 DEBUG GEOparse - SAMPLE: GSM36834
# 19-Nov-2025 09:48:52 DEBUG GEOparse - SAMPLE: GSM36835
# 19-Nov-2025 09:48:52 DEBUG GEOparse - SAMPLE: GSM36836
# 19-Nov-2025 09:48:52 DEBUG GEOparse - SAMPLE: GSM36837
# 19-Nov-2025 09:48:52 DEBUG GEOparse - SAMPLE: GSM36838
# 19-Nov-2025 09:48:52 DEBUG GEOparse - SAMPLE: GSM36839
# 19-Nov-2025 09:48:52 DEBUG GEOparse - SAMPLE: GSM36840
# 19-Nov-2025 09:48:52 DEBUG GEOparse - SAMPLE: GSM36841
# 19-Nov-2025 09:48:52 DEBUG GEOparse - SAMPLE: GSM36842
# 19-Nov-2025 09:48:52 DEBUG GEOparse - SAMPLE: GSM36843
# 19-Nov-2025 09:48:52 DEBUG GEOparse - SAMPLE: GSM36844
# 19-Nov-2025 09:48:52 DEBUG GEOparse - SAMPLE: GSM36845
# 19-Nov-2025 09:48:52 DEBUG GEOparse - SAMPLE: GSM36846
# 19-Nov-2025 09:48:52 DEBUG GEOparse - SAMPLE: GSM36847
# 19-Nov-2025 09:48:52 DEBUG GEOparse - SAMPLE: GSM36848
# 19-Nov-2025 09:48:52 DEBUG GEOparse - SAMPLE: GSM36849
# 19-Nov-2025 09:48:53 DEBUG GEOparse - SAMPLE: GSM36850
# 19-Nov-2025 09:48:53 DEBUG GEOparse - SAMPLE: GSM36851
# 19-Nov-2025 09:48:53 DEBUG GEOparse - SAMPLE: GSM36852
# 19-Nov-2025 09:48:53 DEBUG GEOparse - SAMPLE: GSM36853
# 19-Nov-2025 09:48:53 DEBUG GEOparse - SAMPLE: GSM36854
# 19-Nov-2025 09:48:53 DEBUG GEOparse - SAMPLE: GSM36855
# 19-Nov-2025 09:48:53 DEBUG GEOparse - SAMPLE: GSM36856
# 19-Nov-2025 09:48:53 DEBUG GEOparse - SAMPLE: GSM36857
# 19-Nov-2025 09:48:53 DEBUG GEOparse - SAMPLE: GSM36858
# 19-Nov-2025 09:48:53 DEBUG GEOparse - SAMPLE: GSM36859
# 19-Nov-2025 09:48:53 DEBUG GEOparse - SAMPLE: GSM36860
# 19-Nov-2025 09:48:53 DEBUG GEOparse - SAMPLE: GSM36861
# 19-Nov-2025 09:48:53 DEBUG GEOparse - SAMPLE: GSM36862
# 19-Nov-2025 09:48:53 DEBUG GEOparse - SAMPLE: GSM36863
# 19-Nov-2025 09:48:53 DEBUG GEOparse - SAMPLE: GSM36864
# 19-Nov-2025 09:48:53 DEBUG GEOparse - SAMPLE: GSM36865
# 19-Nov-2025 09:48:53 DEBUG GEOparse - SAMPLE: GSM36866
# 19-Nov-2025 09:48:53 DEBUG GEOparse - SAMPLE: GSM36867
# 19-Nov-2025 09:48:54 DEBUG GEOparse - SAMPLE: GSM36868
# 19-Nov-2025 09:48:54 DEBUG GEOparse - SAMPLE: GSM36869
# 19-Nov-2025 09:48:54 DEBUG GEOparse - SAMPLE: GSM36870
# 19-Nov-2025 09:48:54 DEBUG GEOparse - SAMPLE: GSM36871
# 19-Nov-2025 09:48:54 DEBUG GEOparse - SAMPLE: GSM36872
# 19-Nov-2025 09:48:54 DEBUG GEOparse - SAMPLE: GSM36873
# 19-Nov-2025 09:48:54 DEBUG GEOparse - SAMPLE: GSM36874
# 19-Nov-2025 09:48:54 DEBUG GEOparse - SAMPLE: GSM36875
# 19-Nov-2025 09:48:54 DEBUG GEOparse - SAMPLE: GSM36876
# 19-Nov-2025 09:48:54 DEBUG GEOparse - SAMPLE: GSM36877
# 19-Nov-2025 09:48:54 DEBUG GEOparse - SAMPLE: GSM36878
# 19-Nov-2025 09:48:54 DEBUG GEOparse - SAMPLE: GSM36879
# 19-Nov-2025 09:48:54 DEBUG GEOparse - SAMPLE: GSM36880
# 19-Nov-2025 09:48:54 DEBUG GEOparse - SAMPLE: GSM36881
# 19-Nov-2025 09:48:54 DEBUG GEOparse - SAMPLE: GSM36882
# 19-Nov-2025 09:48:54 DEBUG GEOparse - SAMPLE: GSM36883
# 19-Nov-2025 09:48:55 DEBUG GEOparse - SAMPLE: GSM36884
# 19-Nov-2025 09:48:55 DEBUG GEOparse - SAMPLE: GSM36885
# 19-Nov-2025 09:48:55 DEBUG GEOparse - SAMPLE: GSM36886
# 19-Nov-2025 09:48:55 DEBUG GEOparse - SAMPLE: GSM36887
# 19-Nov-2025 09:48:55 DEBUG GEOparse - SAMPLE: GSM36888
# 19-Nov-2025 09:48:55 DEBUG GEOparse - SAMPLE: GSM36889
# 19-Nov-2025 09:48:55 DEBUG GEOparse - SAMPLE: GSM36890
# 19-Nov-2025 09:48:55 DEBUG GEOparse - SAMPLE: GSM36891
# 19-Nov-2025 09:48:55 DEBUG GEOparse - SAMPLE: GSM36892
# 19-Nov-2025 09:48:55 DEBUG GEOparse - SAMPLE: GSM36893
# 19-Nov-2025 09:48:55 DEBUG GEOparse - SAMPLE: GSM36894
# 19-Nov-2025 09:48:55 DEBUG GEOparse - SAMPLE: GSM36895
# 19-Nov-2025 09:48:55 DEBUG GEOparse - SAMPLE: GSM36896
# 19-Nov-2025 09:48:55 DEBUG GEOparse - SAMPLE: GSM36897
# 19-Nov-2025 09:48:55 DEBUG GEOparse - SAMPLE: GSM36898
# 19-Nov-2025 09:48:55 DEBUG GEOparse - SAMPLE: GSM36899
# 19-Nov-2025 09:48:55 DEBUG GEOparse - SAMPLE: GSM36900
# 19-Nov-2025 09:48:56 DEBUG GEOparse - SAMPLE: GSM36901
# 19-Nov-2025 09:48:56 DEBUG GEOparse - SAMPLE: GSM36902
# 19-Nov-2025 09:48:56 DEBUG GEOparse - SAMPLE: GSM36903
# 19-Nov-2025 09:48:56 DEBUG GEOparse - SAMPLE: GSM36904
# 19-Nov-2025 09:48:56 DEBUG GEOparse - SAMPLE: GSM36905
# 19-Nov-2025 09:48:56 DEBUG GEOparse - SAMPLE: GSM36906
# 19-Nov-2025 09:48:56 DEBUG GEOparse - SAMPLE: GSM36907
# 19-Nov-2025 09:48:56 DEBUG GEOparse - SAMPLE: GSM36908
# 19-Nov-2025 09:48:56 DEBUG GEOparse - SAMPLE: GSM36909
# 19-Nov-2025 09:48:56 DEBUG GEOparse - SAMPLE: GSM36910
# 19-Nov-2025 09:48:56 DEBUG GEOparse - SAMPLE: GSM36911
# 19-Nov-2025 09:48:56 DEBUG GEOparse - SAMPLE: GSM36912
# 19-Nov-2025 09:48:56 DEBUG GEOparse - SAMPLE: GSM36913
# 19-Nov-2025 09:48:56 DEBUG GEOparse - SAMPLE: GSM36914
# 19-Nov-2025 09:48:56 DEBUG GEOparse - SAMPLE: GSM36915
# 19-Nov-2025 09:48:56 DEBUG GEOparse - SAMPLE: GSM36916
# 19-Nov-2025 09:48:56 DEBUG GEOparse - SAMPLE: GSM36917
# 19-Nov-2025 09:48:57 DEBUG GEOparse - SAMPLE: GSM36918
# 19-Nov-2025 09:48:57 DEBUG GEOparse - SAMPLE: GSM36919
# 19-Nov-2025 09:48:57 DEBUG GEOparse - SAMPLE: GSM36920
# 19-Nov-2025 09:48:57 DEBUG GEOparse - SAMPLE: GSM36921
# 19-Nov-2025 09:48:57 DEBUG GEOparse - SAMPLE: GSM36922
# 19-Nov-2025 09:48:57 DEBUG GEOparse - SAMPLE: GSM36923
# 19-Nov-2025 09:48:57 DEBUG GEOparse - SAMPLE: GSM36924
# 19-Nov-2025 09:48:57 DEBUG GEOparse - SAMPLE: GSM36925
# 19-Nov-2025 09:48:57 DEBUG GEOparse - SAMPLE: GSM36926
# 19-Nov-2025 09:48:57 DEBUG GEOparse - SAMPLE: GSM36927
# 19-Nov-2025 09:48:57 DEBUG GEOparse - SAMPLE: GSM36928
# 19-Nov-2025 09:48:57 DEBUG GEOparse - SAMPLE: GSM36929
# 19-Nov-2025 09:48:57 DEBUG GEOparse - SAMPLE: GSM36930
# 19-Nov-2025 09:48:57 DEBUG GEOparse - SAMPLE: GSM36931
# 19-Nov-2025 09:48:57 DEBUG GEOparse - SAMPLE: GSM36932
# 19-Nov-2025 09:48:58 DEBUG GEOparse - SAMPLE: GSM36933
# 19-Nov-2025 09:48:58 DEBUG GEOparse - SAMPLE: GSM36934
# 19-Nov-2025 09:48:58 DEBUG GEOparse - SAMPLE: GSM36935
# 19-Nov-2025 09:48:58 DEBUG GEOparse - SAMPLE: GSM36936
# 19-Nov-2025 09:48:58 DEBUG GEOparse - SAMPLE: GSM36937
# 19-Nov-2025 09:48:58 DEBUG GEOparse - SAMPLE: GSM36938
# 19-Nov-2025 09:48:58 DEBUG GEOparse - SAMPLE: GSM36939
# 19-Nov-2025 09:48:58 DEBUG GEOparse - SAMPLE: GSM36940
# 19-Nov-2025 09:48:58 DEBUG GEOparse - SAMPLE: GSM36941
# 19-Nov-2025 09:48:58 DEBUG GEOparse - SAMPLE: GSM36942
# 19-Nov-2025 09:48:58 DEBUG GEOparse - SAMPLE: GSM36943
# 19-Nov-2025 09:48:58 DEBUG GEOparse - SAMPLE: GSM36944
# 19-Nov-2025 09:48:58 DEBUG GEOparse - SAMPLE: GSM36945
# 19-Nov-2025 09:48:58 DEBUG GEOparse - SAMPLE: GSM36946
# 19-Nov-2025 09:48:59 DEBUG GEOparse - SAMPLE: GSM36947
# 19-Nov-2025 09:48:59 DEBUG GEOparse - SAMPLE: GSM36948
# 19-Nov-2025 09:48:59 DEBUG GEOparse - SAMPLE: GSM36949
# 19-Nov-2025 09:48:59 DEBUG GEOparse - SAMPLE: GSM36950
# 19-Nov-2025 09:48:59 DEBUG GEOparse - SAMPLE: GSM36951
# 19-Nov-2025 09:48:59 DEBUG GEOparse - SAMPLE: GSM36952
# 19-Nov-2025 09:48:59 DEBUG GEOparse - SAMPLE: GSM36953
# 19-Nov-2025 09:48:59 DEBUG GEOparse - SAMPLE: GSM36954
# 19-Nov-2025 09:48:59 DEBUG GEOparse - SAMPLE: GSM36955
# 19-Nov-2025 09:48:59 DEBUG GEOparse - SAMPLE: GSM36956
# 19-Nov-2025 09:48:59 DEBUG GEOparse - SAMPLE: GSM36957
# 19-Nov-2025 09:48:59 DEBUG GEOparse - SAMPLE: GSM36958
# 19-Nov-2025 09:48:59 DEBUG GEOparse - SAMPLE: GSM36959
# 19-Nov-2025 09:48:59 DEBUG GEOparse - SAMPLE: GSM36960
# 19-Nov-2025 09:48:59 DEBUG GEOparse - SAMPLE: GSM36961
# 19-Nov-2025 09:48:59 DEBUG GEOparse - SAMPLE: GSM36962
# 19-Nov-2025 09:49:00 DEBUG GEOparse - SAMPLE: GSM36963
# 19-Nov-2025 09:49:00 DEBUG GEOparse - SAMPLE: GSM36964
# 19-Nov-2025 09:49:00 DEBUG GEOparse - SAMPLE: GSM36965
# 19-Nov-2025 09:49:00 DEBUG GEOparse - SAMPLE: GSM36966
# 19-Nov-2025 09:49:00 DEBUG GEOparse - SAMPLE: GSM36967
# 19-Nov-2025 09:49:00 DEBUG GEOparse - SAMPLE: GSM36968
# 19-Nov-2025 09:49:00 DEBUG GEOparse - SAMPLE: GSM36969
# 19-Nov-2025 09:49:00 DEBUG GEOparse - SAMPLE: GSM36970
# 19-Nov-2025 09:49:00 DEBUG GEOparse - SAMPLE: GSM36971
# 19-Nov-2025 09:49:00 DEBUG GEOparse - SAMPLE: GSM36972
# 19-Nov-2025 09:49:00 DEBUG GEOparse - SAMPLE: GSM36973
# 19-Nov-2025 09:49:00 DEBUG GEOparse - SAMPLE: GSM36974
# 19-Nov-2025 09:49:00 DEBUG GEOparse - SAMPLE: GSM36975
# 19-Nov-2025 09:49:00 DEBUG GEOparse - SAMPLE: GSM36976
# 19-Nov-2025 09:49:00 DEBUG GEOparse - SAMPLE: GSM36977
# 19-Nov-2025 09:49:00 DEBUG GEOparse - SAMPLE: GSM36978
# 19-Nov-2025 09:49:00 DEBUG GEOparse - SAMPLE: GSM36979
# 19-Nov-2025 09:49:01 DEBUG GEOparse - SAMPLE: GSM36980
# 19-Nov-2025 09:49:01 DEBUG GEOparse - SAMPLE: GSM36981
# 19-Nov-2025 09:49:01 DEBUG GEOparse - SAMPLE: GSM36982
# 19-Nov-2025 09:49:01 DEBUG GEOparse - SAMPLE: GSM36983
# 19-Nov-2025 09:49:01 DEBUG GEOparse - SAMPLE: GSM36984
# 19-Nov-2025 09:49:01 DEBUG GEOparse - SAMPLE: GSM36985
# 19-Nov-2025 09:49:01 DEBUG GEOparse - SAMPLE: GSM36986
# 19-Nov-2025 09:49:01 DEBUG GEOparse - SAMPLE: GSM36987
# 19-Nov-2025 09:49:01 DEBUG GEOparse - SAMPLE: GSM36988
# 19-Nov-2025 09:49:01 DEBUG GEOparse - SAMPLE: GSM36989
# 19-Nov-2025 09:49:01 DEBUG GEOparse - SAMPLE: GSM36990
# 19-Nov-2025 09:49:01 DEBUG GEOparse - SAMPLE: GSM36991
# 19-Nov-2025 09:49:01 DEBUG GEOparse - SAMPLE: GSM36992
# 19-Nov-2025 09:49:01 DEBUG GEOparse - SAMPLE: GSM36993
# 19-Nov-2025 09:49:01 DEBUG GEOparse - SAMPLE: GSM36994
# 19-Nov-2025 09:49:02 DEBUG GEOparse - SAMPLE: GSM36995
# 19-Nov-2025 09:49:02 DEBUG GEOparse - SAMPLE: GSM36996
# 19-Nov-2025 09:49:02 DEBUG GEOparse - SAMPLE: GSM36997
# 19-Nov-2025 09:49:02 DEBUG GEOparse - SAMPLE: GSM36998
# 19-Nov-2025 09:49:02 DEBUG GEOparse - SAMPLE: GSM36999
# 19-Nov-2025 09:49:02 DEBUG GEOparse - SAMPLE: GSM37000
# 19-Nov-2025 09:49:02 DEBUG GEOparse - SAMPLE: GSM37001
# 19-Nov-2025 09:49:02 DEBUG GEOparse - SAMPLE: GSM37002
# 19-Nov-2025 09:49:02 DEBUG GEOparse - SAMPLE: GSM37003
# 19-Nov-2025 09:49:02 DEBUG GEOparse - SAMPLE: GSM37004
# 19-Nov-2025 09:49:02 DEBUG GEOparse - SAMPLE: GSM37005
# 19-Nov-2025 09:49:02 DEBUG GEOparse - SAMPLE: GSM37006
# 19-Nov-2025 09:49:02 DEBUG GEOparse - SAMPLE: GSM37007
# 19-Nov-2025 09:49:02 DEBUG GEOparse - SAMPLE: GSM37008
# 19-Nov-2025 09:49:02 DEBUG GEOparse - SAMPLE: GSM37009
# 19-Nov-2025 09:49:03 DEBUG GEOparse - SAMPLE: GSM37010
# 19-Nov-2025 09:49:03 DEBUG GEOparse - SAMPLE: GSM37011
# 19-Nov-2025 09:49:03 DEBUG GEOparse - SAMPLE: GSM37012
# 19-Nov-2025 09:49:03 DEBUG GEOparse - SAMPLE: GSM37013
# 19-Nov-2025 09:49:03 DEBUG GEOparse - SAMPLE: GSM37014
# 19-Nov-2025 09:49:03 DEBUG GEOparse - SAMPLE: GSM37015
# 19-Nov-2025 09:49:03 DEBUG GEOparse - SAMPLE: GSM37016
# 19-Nov-2025 09:49:03 DEBUG GEOparse - SAMPLE: GSM37017
# 19-Nov-2025 09:49:03 DEBUG GEOparse - SAMPLE: GSM37018
# 19-Nov-2025 09:49:03 DEBUG GEOparse - SAMPLE: GSM37019
# 19-Nov-2025 09:49:03 DEBUG GEOparse - SAMPLE: GSM37020
# 19-Nov-2025 09:49:03 DEBUG GEOparse - SAMPLE: GSM37021
# 19-Nov-2025 09:49:03 DEBUG GEOparse - SAMPLE: GSM37022
# 19-Nov-2025 09:49:04 DEBUG GEOparse - SAMPLE: GSM37023
# 19-Nov-2025 09:49:04 DEBUG GEOparse - SAMPLE: GSM37024
# 19-Nov-2025 09:49:04 DEBUG GEOparse - SAMPLE: GSM37025
# 19-Nov-2025 09:49:04 DEBUG GEOparse - SAMPLE: GSM37026
# 19-Nov-2025 09:49:04 DEBUG GEOparse - SAMPLE: GSM37027
# 19-Nov-2025 09:49:04 DEBUG GEOparse - SAMPLE: GSM37028
# 19-Nov-2025 09:49:04 DEBUG GEOparse - SAMPLE: GSM37029
# 19-Nov-2025 09:49:04 DEBUG GEOparse - SAMPLE: GSM37030
# 19-Nov-2025 09:49:04 DEBUG GEOparse - SAMPLE: GSM37031
# 19-Nov-2025 09:49:04 DEBUG GEOparse - SAMPLE: GSM37032
# 19-Nov-2025 09:49:04 DEBUG GEOparse - SAMPLE: GSM37033
# 19-Nov-2025 09:49:04 DEBUG GEOparse - SAMPLE: GSM37034
# 19-Nov-2025 09:49:04 DEBUG GEOparse - SAMPLE: GSM37035
# 19-Nov-2025 09:49:04 DEBUG GEOparse - SAMPLE: GSM37036
# 19-Nov-2025 09:49:04 DEBUG GEOparse - SAMPLE: GSM37037
# 19-Nov-2025 09:49:04 DEBUG GEOparse - SAMPLE: GSM37038
# 19-Nov-2025 09:49:04 DEBUG GEOparse - SAMPLE: GSM37039
# 19-Nov-2025 09:49:05 DEBUG GEOparse - SAMPLE: GSM37040
# 19-Nov-2025 09:49:05 DEBUG GEOparse - SAMPLE: GSM37041
# 19-Nov-2025 09:49:05 DEBUG GEOparse - SAMPLE: GSM37042
# 19-Nov-2025 09:49:05 DEBUG GEOparse - SAMPLE: GSM37043
# 19-Nov-2025 09:49:05 DEBUG GEOparse - SAMPLE: GSM37044
# 19-Nov-2025 09:49:05 DEBUG GEOparse - SAMPLE: GSM37045
# 19-Nov-2025 09:49:05 DEBUG GEOparse - SAMPLE: GSM37046
# 19-Nov-2025 09:49:05 DEBUG GEOparse - SAMPLE: GSM37047
# 19-Nov-2025 09:49:05 DEBUG GEOparse - SAMPLE: GSM37048
# 19-Nov-2025 09:49:05 DEBUG GEOparse - SAMPLE: GSM37049
# 19-Nov-2025 09:49:05 DEBUG GEOparse - SAMPLE: GSM37050
# 19-Nov-2025 09:49:05 DEBUG GEOparse - SAMPLE: GSM37051
# 19-Nov-2025 09:49:05 DEBUG GEOparse - SAMPLE: GSM37052
# 19-Nov-2025 09:49:05 DEBUG GEOparse - SAMPLE: GSM37053
# 19-Nov-2025 09:49:05 DEBUG GEOparse - SAMPLE: GSM37054
# 19-Nov-2025 09:49:05 DEBUG GEOparse - SAMPLE: GSM37055
# 19-Nov-2025 09:49:05 DEBUG GEOparse - SAMPLE: GSM37056
# 19-Nov-2025 09:49:05 DEBUG GEOparse - SAMPLE: GSM37057
# 19-Nov-2025 09:49:06 DEBUG GEOparse - SAMPLE: GSM37058
# 19-Nov-2025 09:49:06 DEBUG GEOparse - SAMPLE: GSM37059
# 19-Nov-2025 09:49:06 DEBUG GEOparse - SAMPLE: GSM37060
# 19-Nov-2025 09:49:06 DEBUG GEOparse - SAMPLE: GSM37061
# 19-Nov-2025 09:49:06 DEBUG GEOparse - SAMPLE: GSM37062
# <SERIES: GSE2034 - 286 SAMPLES, 1 d(s)>
# Number of samples (GSM): 286
# Number of platforms (GPL): 1
# Platforms: ['GPL96']

# %%
# Peek at study-level metadata
pd.set_option("display.max_rows", 20)
meta = pd.Series({k: v[0] if isinstance(v, list) and len(v) == 1 else v 
                  for k, v in gse.metadata.items()})
meta.head(30)
# Out:
# title                               Breast cancer relapse free survival
# geo_accession                                                   GSE2034
# status                                            Public on Feb 23 2005
# submission_date                                             Dec 03 2004
# last_update_date                                            Aug 10 2018
#                                             ...
# supplementary_file    ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE2nnn/...
# platform_id                                                       GPL96
# platform_taxid                                                     9606
# sample_taxid                                                       9606
# relation              BioProject: https://www.ncbi.nlm.nih.gov/biopr...
# Length: 23, dtype: object

# %%
# Inspect sample (GSM) annotation: characteristics_ch1 often holds phenotype fields
def extract_gsm_meta(gsm):
    row = {"gsm": gsm.name}
    for k, v in gsm.metadata.items():
        if isinstance(v, list):
            row[k] = "; ".join(map(str, v))
        else:
            row[k] = v
    # Also flatten common fields inside .table if present
    if hasattr(gsm, "table") and isinstance(gsm.table, pd.DataFrame):
        for col in ["title", "source_name_ch1"]:
            if col in gsm.table.columns:
                row[col] = "; ".join(gsm.table[col].astype(str).unique())
    return row

gsm_meta = pd.DataFrame([extract_gsm_meta(gsm) for gsm in gse.gsms.values()])
print("GSM meta shape:", gsm_meta.shape)
display(gsm_meta.head(10))
# Save for later
gsm_meta.to_csv(DATA_PROCESSED / f"{gse_id}_gsm_metadata.csv", index=False)
# Out:
# GSM meta shape: (286, 28)
#         gsm              title geo_accession                 status  \
# 0  GSM36777    Wang4812_JA_277      GSM36777  Public on Feb 23 2005
# 1  GSM36778    Wang4813_JA_278      GSM36778  Public on Feb 23 2005
# 2  GSM36779   Wang4630_JA798@C      GSM36779  Public on Feb 23 2005
# 3  GSM36780  Wang4889_JA_846@2      GSM36780  Public on Feb 23 2005
# 4  GSM36781  Wang4857_JA_765@2      GSM36781  Public on Feb 23 2005
# 5  GSM36782     Wang4585_JA600      GSM36782  Public on Feb 23 2005
# 6  GSM36783     Wang4586_JA601      GSM36783  Public on Feb 23 2005
# 7  GSM36784     Wang4587_JA602      GSM36784  Public on Feb 23 2005
# 8  GSM36785    Wang4820_JA_605      GSM36785  Public on Feb 23 2005
# 9  GSM36786    Wang4821_JA_606      GSM36786  Public on Feb 23 2005
#
#   submission_date last_update_date type channel_count source_name_ch1  \
# 0     Dec 03 2004      May 31 2013  RNA             1          Breast
# 1     Dec 03 2004      May 31 2013  RNA             1          Breast
# 2     Dec 03 2004      May 31 2013  RNA             1          Breast
# 3     Dec 03 2004      May 31 2013  RNA             1          Breast
# 4     Dec 03 2004      May 31 2013  RNA             1          Breast
# 5     Dec 03 2004      May 31 2013  RNA             1          Breast
# 6     Dec 03 2004      May 31 2013  RNA             1          Breast
# 7     Dec 03 2004      May 31 2013  RNA             1          Breast
# 8     Dec 03 2004      May 31 2013  RNA             1          Breast
# 9     Dec 03 2004      Apr 02 2012  RNA             1          Breast
#
#    organism_ch1  ... contact_institute contact_address contact_city  \
# 0  Homo sapiens  ...           Veridex                    San Diego
# 1  Homo sapiens  ...           Veridex                    San Diego
# 2  Homo sapiens  ...           Veridex                    San Diego
# 3  Homo sapiens  ...           Veridex                    San Diego
# 4  Homo sapiens  ...           Veridex                    San Diego
# 5  Homo sapiens  ...           Veridex                    San Diego
# 6  Homo sapiens  ...           Veridex                    San Diego
# 7  Homo sapiens  ...           Veridex                    San Diego
# 8  Homo sapiens  ...           Veridex                    San Diego
# 9  Homo sapiens  ...           Veridex                    San Diego
#
#   contact_state contact_zip/postal_code contact_country  \
# 0            CA                   92121             USA
# 1            CA                   92121             USA
# 2            CA                   92121             USA
# 3            CA                   92121             USA
# 4            CA                   92121             USA
# 5            CA                   92121             USA
# 6            CA                   92121             USA
# 7            CA                   92121             USA
# 8            CA                   92121             USA
# 9            CA                   92121             USA
#
#                                   supplementary_file                 relation  \
# 0  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM36nn...  Reanalyzed by: GSE47561
# 1  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM36nn...  Reanalyzed by: GSE47561
# 2  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM36nn...  Reanalyzed by: GSE47561
# 3  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM36nn...  Reanalyzed by: GSE47561
# 4  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM36nn...  Reanalyzed by: GSE47561
# 5  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM36nn...  Reanalyzed by: GSE47561
# 6  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM36nn...  Reanalyzed by: GSE47561
# 7  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM36nn...  Reanalyzed by: GSE47561
# 8  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM36nn...  Reanalyzed by: GSE47561
# 9  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM36nn...                      NaN
#
#   series_id data_row_count
# 0   GSE2034          22283
# 1   GSE2034          22283
# 2   GSE2034          22283
# 3   GSE2034          22283
# 4   GSE2034          22283
# 5   GSE2034          22283
# 6   GSE2034          22283
# 7   GSE2034          22283
# 8   GSE2034          22283
# 9   GSE2034          22283
#
# [10 rows x 28 columns]

# %%
# Build expression matrix: probes (rows) × samples (columns) by pivoting VALUE
# This works if GSM.tables contain a 'VALUE' column (typical for microarrays)
expr = gse.pivot_samples('VALUE')  # rows: probes, columns: GSM IDs
print("Expression shape:", expr.shape)
display(expr.iloc[:5, :10])
# Save
expr.to_parquet(DATA_PROCESSED / f"{gse_id}_expr_probe.parquet")
expr.to_csv(DATA_PROCESSED / f"{gse_id}_expr_probe.csv")
# Out:
# Expression shape: (22283, 286)
# name       GSM36777  GSM36778  GSM36779  GSM36780  GSM36781  GSM36782  \
# ID_REF
# 1007_s_at    3848.1    6520.9    5285.7    4043.7    4263.6    2949.8
# 1053_at       228.9     112.5     178.4     398.7     417.7     221.2
# 117_at        213.1     189.8     269.7     312.4     327.1     225.0
# 121_at       1009.4    2083.3    1203.4    1104.4    1043.3    1117.6
# 1255_g_at      31.8     145.8      42.5     108.2      69.2      47.4
#
# name       GSM36783  GSM36784  GSM36785  GSM36786
# ID_REF
# 1007_s_at    5498.9    3863.1    3370.4    3991.9
# 1053_at       280.4     198.2     304.7     198.2
# 117_at        243.5     244.4     348.5     185.3
# 121_at       1085.4    1423.1    1196.4     993.3
# 1255_g_at      84.3     102.0      22.8      86.3

# %%
# Try mapping probes to gene symbols using primary platform (first GPL)
# Note: Field names differ across platforms; we attempt a best-effort mapping.

primary_gpl = list(gse.gpls.values())[0]
gpl_tbl = primary_gpl.table.copy()
print("GPL table columns:", list(gpl_tbl.columns)[:20])

# Common candidate columns
candidate_gene_cols = [
    "Gene Symbol", "GENE_SYMBOL", "Symbol", "Gene symbol", "GeneSymbol", "SYMBOL"
]
candidate_id_cols = ["ID", "Probe ID", "ID_REF"]

def first_present(cols, df):
    return next((c for c in cols if c in df.columns), None)

gene_col = first_present(candidate_gene_cols, gpl_tbl)
id_col = first_present(candidate_id_cols, gpl_tbl)

if gene_col and id_col:
    map_df = gpl_tbl[[id_col, gene_col]].rename(columns={id_col: "probe_id", gene_col: "gene"})
    map_df["gene"] = map_df["gene"].fillna("").astype(str).str.split(" /// ").str[0].str.strip()
    print(map_df.head())

    # Collapse probes to genes (mean across probes per gene, ignoring empty gene labels)
    valid = map_df.query("gene != ''")
    expr_gene = (
        expr
        .merge(valid, left_index=True, right_on="probe_id", how="inner")
        .drop(columns=["probe_id"])
        .groupby("gene", as_index=True).mean(numeric_only=True)
        .sort_index()
    )
    print("Gene-level matrix:", expr_gene.shape)
    display(expr_gene.iloc[:5, :5])

    expr_gene.to_parquet(DATA_PROCESSED / f"{gse_id}_expr_gene.parquet")
    expr_gene.to_csv(DATA_PROCESSED / f"{gse_id}_expr_gene.csv")
else:
    print("Could not find expected probe/gene columns on GPL; keeping probe-level matrix.")
# Out:
# GPL table columns: ['ID', 'GB_ACC', 'SPOT_ID', 'Species Scientific Name', 'Annotation Date', 'Sequence Type', 'Sequence Source', 'Target Description', 'Representative Public ID', 'Gene Title', 'Gene Symbol', 'ENTREZ_GENE_ID', 'RefSeq Transcript ID', 'Gene Ontology Biological Process', 'Gene Ontology Cellular Component', 'Gene Ontology Molecular Function']
#     probe_id    gene
# 0  1007_s_at    DDR1
# 1    1053_at    RFC2
# 2     117_at   HSPA6
# 3     121_at    PAX8
# 4  1255_g_at  GUCA1A
# Gene-level matrix: (13237, 286)
#         GSM36777  GSM36778  GSM36779  GSM36780  GSM36781
# gene
# A1CF       279.7     659.5     249.3     366.6     457.8
# A2M       3885.5    3382.9    4260.2    5263.7    3906.1
# A4GALT     159.1      84.6      94.1      83.2      80.3
# A4GNT      291.1     213.2     270.7     260.6     219.3
# AAAS       213.0      34.1     236.3      81.5     146.4

# %%
# Basic sanity checks & simple EDA
def summarize_matrix(M):
    s = pd.DataFrame({
        "n_genes_or_probes": [M.shape[0]],
        "n_samples": [M.shape[1]],
        "min": [float(np.nanmin(M.values))],
        "max": [float(np.nanmax(M.values))],
        "mean": [float(np.nanmean(M.values))],
        "std": [float(np.nanstd(M.values))],
        "missing_vals": [int(np.isnan(M.values).sum())],
    })
    return s

probe_summary = summarize_matrix(expr)
display(probe_summary)

# If gene-level exists, summarize too
gene_path = DATA_PROCESSED / f"{gse_id}_expr_gene.parquet"
if gene_path.exists():
    expr_gene = pd.read_parquet(gene_path)
    gene_summary = summarize_matrix(expr_gene)
    display(gene_summary)
# Out:
#    n_genes_or_probes  n_samples  min       max        mean          std  \
# 0              22283        286  0.1  157291.8  964.580996  3317.334678
#
#    missing_vals
# 0             0
#    n_genes_or_probes  n_samples  min      max        mean         std  \
# 0              13237        286  0.1  99725.9  890.305044  2632.25999
#
#    missing_vals
# 0             0

# %% [markdown]
# ## Next steps
#
# - **02_preprocess_standardize.ipynb**: log transform (if needed), standardize per gene, handle missing values.
# - **03_distance_clustering.ipynb**: compute correlation distance (1 - Pearson r), hierarchical clustering (Ward linkage).
# - **04_bootstrap_stability.ipynb**: bootstrap resampling to assess cluster stability.
# - **05_enrichment.ipynb**: run per-cluster enrichment (e.g., MSigDB) using `gseapy`.
